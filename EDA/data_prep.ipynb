# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# At first glance, we dispose the officials, draft combine stats, draft history, player logs, score

# %%
games = pd.read_csv('./Datasets/nba_dataset/csv/game.csv')
players = pd.read_csv('./Datasets/nba_dataset/csv/player.csv')

# %%
games
# Out:
#        season_id  team_id_home team_abbreviation_home  \
# 0          21946    1610610035                    HUS
# 1          21946    1610610034                    BOM
# 2          21946    1610610032                    PRO
# 3          21946    1610610025                    CHS
# 4          21946    1610610028                    DEF
# ...          ...           ...                    ...
# 64287      22022    1610612738                    BOS
# 64288      22022    1610612750                    MIN
# 64289      22022    1610612757                    POR
# 64290      22022    1610612756                    PHX
# 64291      22022    1610612765                    DET
#
#                 team_name_home   game_id            game_date matchup_home  \
# 0              Toronto Huskies  24600001  1946-11-01 00:00:00  HUS vs. NYK
# 1            St. Louis Bombers  24600003  1946-11-02 00:00:00  BOM vs. PIT
# 2      Providence Steamrollers  24600002  1946-11-02 00:00:00  PRO vs. BOS
# ...

# %%
teams = pd.read_csv('./Datasets/nba_dataset/csv/team.csv')
teams
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %%
players
# Out:
#            id            full_name first_name     last_name  is_active
# 0       76001       Alaa Abdelnaby       Alaa     Abdelnaby          0
# 1       76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz          0
# 2       76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar          0
# 3          51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf          0
# 4        1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad          0
# ...       ...                  ...        ...           ...        ...
# 4826  1627790           Ante Zizic       Ante         Zizic          0
# 4827    78647             Jim Zoet        Jim          Zoet          0
# 4828    78648            Bill Zopf       Bill          Zopf          0
# 4829  1627826          Ivica Zubac      Ivica         Zubac          1
# 4830    78650           Matt Zunic       Matt         Zunic          0
#
# [4831 rows x 5 columns]

# %%
common_player_info = pd.read_csv('./Datasets/nba_dataset/csv/common_player_info.csv')
common_player_info.drop(common_player_info.columns[[4,5,6,8,10,13,16,17,21,23,26,27,28,29,30,31,32]], axis=1, inplace=True)

common_player_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4215 entries, 0 to 4214
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   person_id           4215 non-null   int64
#  1   first_name          4214 non-null   object
#  2   last_name           4215 non-null   object
#  3   display_first_last  4215 non-null   object
#  4   birthdate           4215 non-null   object
#  5   country             4214 non-null   object
#  6   height              4108 non-null   object
#  7   weight              4104 non-null   float64
#  8   jersey              3243 non-null   object
#  9   position            4138 non-null   object
#  10  team_id             4215 non-null   int64
#  11  team_name           3523 non-null   object
#  12  team_abbreviation   3523 non-null   object
#  13  team_city           3523 non-null   object
#  14  from_year           4193 non-null   float64
# ...

# %% [markdown]
# # Dataset - Player Data per season

# %% [markdown]
# Stats glossary:
#  - G: Games
#  - GS:
#  - MP: Minutes Played
#  - PER: Player Efficiency Rating
#  - TS%: True Shooting Percentage
#  - 3PAr: 3-Point Attempt Rate
#  - FTr: Free-Throws rate
#  - ORB%: Offensive Rebound percentage
#  - DRB%: Deffensive Rebound percentage
#  - TRB%: Total Rebound Percentage
#  - AST%: assists percentage
#  - STL%: steals percentage
#  - BLK%: blocks percentage
#  - TOV%: Turnover percentage
#  - USG%: Usage rate (involvement)
#  - blanl ??
#  - OWS: Offensive Win shares
#  - DWS: Deffensive Win shares
#  - WS: Win shares
#  - OBPM: Offensive Box Plus/Minus
#  - DBPM: Deffensive Blocks Plus/Minus
#  - BPM: Box Plus/Minus
#  - VORP: Value Over Replacement Player
#  - FG: Field Goals (any shot taken from the court during play)
#  - FGA: Field Goals Attempted
#  - FG%: Field Goals Percentage
#  - 3P: 3-point
#  - 3PA: 3-point attempted
#  - 3P%: 3-point percentage
#  - 2P: 2-point
#  - 2PA: 2-point attempted
#  - 2P%: 2-point percentage
#  - eFG%: Effective Field Goal percentage
#  - FT: Free Throw
#  - FTA: Free Throws Attempted
#  - FT%: Free Throws percentage
#  - ORB: Offensive Rebound
#  - DRB: Deffensive Rebound
#  - TRB: Total Rebound
#  - AST: Assists
#  - STL: Steals
#  - BLK: Blocks
#  - TOV: Turnovers
#  - PF: Personal Fouls
#  - PTS: Points

# %% [markdown]
# At a first glance we see some columns that will not be necessary or are too detailed for the work proposed: VORP,

# %%
player_stats = pd.read_csv('./Datasets/archive/Seasons_Stats.csv')

player_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24691 entries, 0 to 24690
# Data columns (total 53 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  24691 non-null  int64
#  1   Year        24624 non-null  float64
#  2   Player      24624 non-null  object
#  3   Pos         24624 non-null  object
#  4   Age         24616 non-null  float64
#  5   Tm          24624 non-null  object
#  6   G           24624 non-null  float64
#  7   GS          18233 non-null  float64
#  8   MP          24138 non-null  float64
#  9   PER         24101 non-null  float64
#  10  TS%         24538 non-null  float64
#  11  3PAr        18839 non-null  float64
#  12  FTr         24525 non-null  float64
#  13  ORB%        20792 non-null  float64
#  14  DRB%        20792 non-null  float64
#  15  TRB%        21571 non-null  float64
#  16  AST%        22555 non-null  float64
#  17  STL%        20792 non-null  float64
# ...

# %% [markdown]
# # Dataset - Team Season Stats

# %% [markdown]
#  - G: 	Games
#  - Gs: 	Games Started
#  - Min: 	Minutes
#  - Pts: 	Points
#  - Reb: 	Rebounds
#  - Oreb: 	Offensive Rebounds
#  - Dreb: 	Defensive Rebounds
#  - Ast:	Assists
#  - Stl: 	Steals
#  - Blk: 	Blocks
#  - To: 	Turnovers
#  - Pf: 	Fouls
#  - Fgm-a: 	Field goals made - Field goals attempts
#  - 3gm-a: 	3-point made - 3-point attempts
#  - Ftm-a: 	Free throws made - Free throws attempts
#  - Pct: 	Percentage
#  - Off: 	Offense
#  - Def: 	Defense
#  - Res: 	Result
#  - W: 	Win
#  - L: 	Loss
#  - Deff: 	Efficiency Recap Difference = Efficiency Recap - Opponent's Efficiency Recap
#  - Eff: 	NBA Efficiency recap = ((Points + Rebounds + Assists + Steals + Blocks) - ((Field goals attempts - Field goals made) + (Free throws attempts - Free throws made) + Turnovers))
#  - Conf: 	Conference
#  - Div 	Division
#  - In-The-Paint Stats: 	Power-Forward + Center Stats
#  - Out-The-Paint Stats: 	Point Guard + Shooting Guard + Small-Forward Stats
#  - Backcourt Stats: 	Point Guard + Shooting Guard Stats
#  - Frontourt Stats: 	Small-Forward + Power-Forward + Center Stats
#  - Rkg: 	Ranking = (Points + Rebounds + Assists + Steals + Blocks + Fouls Drawn + Free Throws Made + Field goals Made + 3-point Made - Turnovers - Blocks Against - Fouls - Free throws attempts - Field goals Attempts - 3-point Attempts)
#  - Efg %: 	Effective Field Goal Percentage = (Field goals Made+ 0.5*3-point Made)/Field goals Attempts
#  - TS % 	True Shooting Percentage = Points/(2*(Field goals Attempts+0.44*Free throws attempts)).

# %%
team_stats = pd.read_csv('./Datasets/NBA_Team_Stats.csv')
team_stats
# Out:
#      No           Team    G   Min    Pts   Reb   Ast  Stl  Blk    To  ...  \
# 0     1        Chicago  103  48.4   96.0  44.1  23.1  8.6  4.3  13.0  ...
# 1     2           Utah  102  48.3   98.6  40.8  24.7  7.6  4.8  14.7  ...
# 2     3        Phoenix   86  48.6   99.3  41.9  25.6  9.2  5.3  14.4  ...
# 3     4     L.A.Lakers   95  48.3  104.8  42.9  24.3  8.7  6.8  14.7  ...
# 4     5    San Antonio   91  48.4   92.5  44.1  21.9  6.2  6.9  15.3  ...
# ..   ..            ...  ...   ...    ...   ...   ...  ...  ...   ...  ...
# 720  25     Sacramento   82  48.3  110.3  42.9  23.7  7.2  4.5  13.5  ...
# 721  26        Orlando   82  48.2  104.2  44.3  23.7  6.8  4.5  13.8  ...
# 722  27        Detroit   82  48.2  104.8  43.0  23.5  7.7  4.8  13.4  ...
# 723  28       Portland   82  48.1  106.2  42.9  22.9  8.0  4.5  13.7  ...
# 724  29  Oklahoma City   82  48.3  103.7  45.6  22.2  7.6  4.6  13.3  ...
#
#      Oreb      Fgm-a    Pct      3gm-a  Pct.1      Ftm-a  Pct.2    Eff  Deff  \
# ...

# %%
print(team_stats['Team'].info())
print(teams[['id', 'city', 'nickname', 'abbreviation']])
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 695 entries, 8 to 717
# Series name: Team
# Non-Null Count  Dtype
# --------------  -----
# 695 non-null    object
# dtypes: object(1)
# memory usage: 10.9+ KB
# None
#             id           city       nickname abbreviation
# 0   1610612737        Atlanta          Hawks          ATL
# 1   1610612738         Boston        Celtics          BOS
# 14  1610612751       Brooklyn           Nets          BKN
# 29  1610612766      Charlotte        Hornets          CHA
# 4   1610612741        Chicago          Bulls          CHI
# 2   1610612739      Cleveland      Cavaliers          CLE
# 5   1610612742         Dallas      Mavericks          DAL
# 6   1610612743         Denver        Nuggets          DEN
# 28  1610612765        Detroit        Pistons          DET
# 7   1610612744   Golden State       Warriors          GSW
# 8   1610612745        Houston        Rockets          HOU
# 17  1610612754        Indiana         Pacers          IND
# ...

# %% [markdown]
# Seattle, New Jersey and Vancouver not in the NBA so they will be removed

# %%
team_stats = team_stats[team_stats["Team"] != "Seattle"]
team_stats = team_stats[team_stats["Team"] != "New Jersey"]
team_stats = team_stats[team_stats["Team"] != "Vancouver"]

# %%
team_stats = team_stats.sort_values(['Team', 'Year'], ascending=(True, True))
team_stats
# Out:
#      No        Team   G   Min    Pts   Reb   Ast  Stl  Blk    To  ...  Oreb  \
# 8     9     Atlanta  86  48.5   95.5  42.8  19.0  8.0  5.9  14.0  ...  13.4
# 43   15     Atlanta  59  48.3   85.3  42.8  15.4  7.1  5.0  14.0  ...  13.3
# 82   25     Atlanta  82  48.4   94.3  45.3  18.9  6.1  5.6  14.9  ...  14.0
# 110  24     Atlanta  82  48.1   91.0  42.9  19.0  7.7  4.7  15.8  ...  12.5
# 139  24     Atlanta  82  48.2   94.0  41.5  20.2  8.1  4.3  14.7  ...  11.6
# ..   ..         ...  ..   ...    ...   ...   ...  ...  ...   ...  ...   ...
# 588   9  Washington  88  48.4  106.6  42.8  25.1  7.9  4.3  13.9  ...   9.9
# 631  23  Washington  82  48.6  114.0  42.3  26.3  8.3  4.6  13.6  ...   9.7
# 659  22  Washington  72  48.2  114.4  42.1  25.0  8.0  4.3  13.5  ...  10.2
# 686  20  Washington  79  48.3  116.3  45.2  25.3  7.1  4.3  13.9  ...   9.7
# 717  22  Washington  82  48.4  108.6  43.1  25.0  6.4  5.0  12.6  ...   9.0
#
# ...

# %%
team_city = team_stats['Team'].to_numpy()

# %%
team_city = team_stats['Team'].to_numpy()

unique = ['Chicago','Utah','Phoenix','L.A.Lakers','San Antonio','Indiana', 
          'Miami','Atlanta','New York','Cleveland','Charlotte','Portland',
          'Minnesota','Washington','Detroit','Milwaukee','Orlando',
          'Houston','Boston','Philadelphia','Sacramento','Dallas',
          'L.A.Clippers','Golden State','Toronto','Denver','Memphis','New Orleans',
          'Oklahoma City','Brooklyn']

team_names = ['Bulls', 'Jazz', 'Suns', 'Lakers', 'Spurs', 'Pacers', 'Heat', 'Hawks', 
              'Knicks', 'Cavaliers', 'Hornets', 'Trail Blazers', 
              'Timberwolves', 'Wizards','Pistons', 'Bucks', 'Magic', 
              'Rockets', 'Celtics', '76ers', 'Kings','Mavericks', 'Clippers', 
              'Warriors', 'Raptors', 'Nuggets', 'Grizzlies','Pelicans', 
              'Thunder', 'Nets']

team_abb = ['CHI', 'UTA', 'PHX', 'LAL', 'SAS', 'IND', 'MIA', 'ATL', 'NYK', 
            'CLE', 'CHA', 'POR', 'MIN', 'WAS', 'DET', 'MIL', 'ORL',
            'HOU', 'BOS', 'PHI', 'SAC', 'DAL', 'LAC', 'GSW', 'TOR', 
            'DEN', 'MEM', 'NOP', 'OKC', 'BKN']

team_state = ['Chicago', 'Utah', 'California', 'Texas', 'Indiana', 'Florida',
              'Atlanta', 'New York', 'Ohio', 'North Carolina', 'Oregon', 
              'Minnesota', ]


col1 = []
col2 = []
for i in team_city:
    ind = unique.index(i)
    col1.append(team_names[ind])
    col2.append(team_abb[ind])
    
print(len(col1), len(col2))

team_stats.insert(2, "Team_name", col1)
team_stats.insert(3, "Team_abb", col2)
# Out:
# 695 695

# %%
teams = pd.read_csv('./Datasets/nba_dataset/csv/team.csv')

teams = teams.sort_values(['city'], ascending=(True))
team_city = team_stats['Team'].to_numpy()
teams.drop(['year_founded'], axis= 1, inplace=True)

unique = ['Chicago','Utah','Phoenix','L.A.Lakers','San Antonio','Indiana', 
          'Miami','Atlanta','New York','Cleveland','Charlotte','Portland',
          'Minnesota','Washington','Detroit','Milwaukee','Orlando',
          'Houston','Boston','Philadelphia','Sacramento','Dallas',
          'L.A.Clippers','Golden State','Toronto','Denver','Memphis','New Orleans',
          'Oklahoma City','Brooklyn']

unique.sort()

#array = np.empty([team_stats.shape[0], teams.shape[1]])
array = []
print(team_stats.shape, teams.shape)
it=0
for t in team_city:
    ind = unique.index(t)
    #array[it,:] = teams.iloc[ind,:]
    array.append(teams.iloc[ind,:].to_numpy())
    it+=1

print(len(array))

array = np.array(array).reshape(len(array), 6)
array.shape
print(array)
# Out:
# (695, 22) (30, 6)
# 695
# [[1610612737 'Atlanta Hawks' 'ATL' 'Hawks' 'Atlanta' 'Atlanta']
#  [1610612737 'Atlanta Hawks' 'ATL' 'Hawks' 'Atlanta' 'Atlanta']
#  [1610612737 'Atlanta Hawks' 'ATL' 'Hawks' 'Atlanta' 'Atlanta']
#  ...
#  [1610612764 'Washington Wizards' 'WAS' 'Wizards' 'Washington'
#   'District of Columbia']
#  [1610612764 'Washington Wizards' 'WAS' 'Wizards' 'Washington'
#   'District of Columbia']
#  [1610612764 'Washington Wizards' 'WAS' 'Wizards' 'Washington'
#   'District of Columbia']]

# %%
team_stats.drop(['Team'], axis=1, inplace=True)

team_stats.insert(1, "id", array[:,0])
team_stats.insert(2, "full_name", array[:,1])
team_stats.insert(3, "abb", array[:,2])
team_stats.insert(4, "nickname", array[:,3])
team_stats.insert(5, "city", array[:,4])
team_stats.insert(6, "state", array[:,5])

# %%
team_stats

team_stats.to_csv('Clean_./Datasets/team_stats_season.csv')

# %%
teams = teams.sort_values(['city'], ascending=(True))
teams
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 14  1610612751           Brooklyn Nets          BKN           Nets
# 29  1610612766       Charlotte Hornets          CHA        Hornets
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 28  1610612765         Detroit Pistons          DET        Pistons
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 17  1610612754          Indiana Pacers          IND         Pacers
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# ...

# %%
team_stats.head(5)
# Out:
#    No         Team     Team_state    Team_city Team_abb Team_name    G   Min  \
# 0   1      Chicago        Atlanta      Atlanta      ATL     Bulls  103  48.4
# 1   2         Utah  Massachusetts       Boston      BOS      Jazz  102  48.3
# 2   3      Phoenix           Ohio    Cleveland      CLE      Suns   86  48.6
# 3   4   L.A.Lakers      Louisiana  New Orleans      NOP    Lakers   95  48.3
# 4   5  San Antonio       Illinois      Chicago      CHI     Spurs   91  48.4
#
#      Pts   Reb  ...  Oreb      Fgm-a    Pct     3gm-a  Pct.1      Ftm-a  \
# 0   96.0  44.1  ...  14.9  36.7-81.7  0.449  3.9-12.0  0.323  18.7-25.2
# 1   98.6  40.8  ...  11.3  35.9-74.3  0.483   3.1-8.4  0.368  23.8-30.9
# 2   99.3  41.9  ...  12.1  38.2-82.0  0.466  5.2-14.7  0.355  17.7-23.6
# 3  104.8  42.9  ...  13.2  38.0-79.1  0.480  6.1-17.3  0.350  22.8-33.7
# 4   92.5  44.1  ...  11.9  35.1-75.1  0.468  3.7-10.8  0.344  18.5-26.8
#
#    Pct.2    Eff  Deff       Year
# 0  0.741  111.6  17.5  1997-1998
# ...
